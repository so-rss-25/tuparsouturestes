# %% [markdown]
# # Import du fichier et analyse globale

# %%
import pandas as pd
import builtins
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
url = f"https://docs.google.com/spreadsheets/d/1PIMO76csrwWa7eRCZHQziJQvqGMy7M_EpZLblZjRFMU/gviz/tq?tqx=out:csv&sheet=dataset_clean"
df = pd.read_csv(url)
df
# Out:
#       age attrition deplacements_pro service  trajet_quotidien_en_miles  \
# 0      41       Oui             Rare  Ventes                          1
# 1      49       Non         Fréquent     R&D                          8
# 2      37       Oui             Rare     R&D                          2
# 3      33       Non         Fréquent     R&D                          3
# 4      27       Non             Rare     R&D                          2
# ...   ...       ...              ...     ...                        ...
# 1465   36       Non         Fréquent     R&D                         23
# 1466   39       Non             Rare     R&D                          6
# 1467   27       Non             Rare     R&D                          4
# 1468   49       Non         Fréquent  Ventes                          2
# 1469   34       Non             Rare     R&D                          8
#
#       num_niveau_detude domaine_detude  identifiant_employe  \
# 0                     2       Sciences                    1
# 1                     1       Sciences                    2
# 2                     2          Autre                    4
# 3                     4       Sciences                    5
# 4                     1       Médecine                    7
# ...                 ...            ...                  ...
# 1465                  2       Médecine                 2061
# 1466                  1       Médecine                 2062
# 1467                  3       Sciences                 2064
# 1468                  3       Médecine                 2065
# 1469                  3       Médecine                 2068
#
#       num_satisfaction_environnement  genre  ...  pourcentage_augmentation  \
# 0                                  2  Femme  ...                   11 - 12
# 1                                  3  Homme  ...                      21 +
# 2                                  4  Homme  ...                   15 - 20
# 3                                  4  Femme  ...                   11 - 12
# 4                                  1  Homme  ...                   11 - 12
# ...                              ...    ...  ...                       ...
# 1465                               3  Homme  ...                   15 - 20
# 1466                               4  Homme  ...                   15 - 20
# 1467                               2  Homme  ...                   15 - 20
# 1468                               4  Homme  ...                   13 - 14
# 1469                               2  Homme  ...                   11 - 12
#
#       niveau_carriere temps_de_formation  anciennete anciennete_poste  \
# 0             06 - 10                  0     06 - 10          03 - 05
# 1             06 - 10            01 - 03     06 - 10          06 - 10
# 2             06 - 10            01 - 03      0 - 02           0 - 02
# 3             06 - 10            01 - 03     06 - 10          06 - 10
# 4             06 - 10            01 - 03      0 - 02           0 - 02
# ...               ...                ...         ...              ...
# 1465          10 - 20            01 - 03     03 - 05           0 - 02
# 1466          06 - 10               04 +     06 - 10          06 - 10
# 1467          06 - 10                  0     06 - 10           0 - 02
# 1468          10 - 20            01 - 03     06 - 10          06 - 10
# 1469          06 - 10            01 - 03     03 - 05          03 - 05
#
#       derniere_promotion  annees_avec_manager     prenom         nom  \
# 0                 0 - 02              03 - 05       Rose      Atkins
# 1                 0 - 02              06 - 10    Timothy       Davis
# 2                 0 - 02               0 - 02     Harold      Newman
# 3                03 - 05               0 - 02   Michelle       Olson
# 4                 0 - 02               0 - 02    Richard       Riley
# ...                  ...                  ...        ...         ...
# 1465              0 - 02              03 - 05      Ricky     Johnson
# 1466              0 - 02              06 - 10     Carlos      Holmes
# 1467              0 - 02              03 - 05  Alejandro  Mclaughlin
# 1468              0 - 02              06 - 10      Roger       Green
# 1469              0 - 02               0 - 02     Daniel       Jones
#
#                           email
# 0         r.atkins@ibm-data.com
# 1          t.davis@ibm-data.com
# 2         h.newman@ibm-data.com
# 3          m.olson@ibm-data.com
# 4          r.riley@ibm-data.com
# ...                         ...
# 1465    r.johnson1@ibm-data.com
# 1466      c.holmes@ibm-data.com
# 1467  a.mclaughlin@ibm-data.com
# 1468       r.green@ibm-data.com
# 1469      d.jones3@ibm-data.com
#
# [1470 rows x 54 columns]

# %%
df.columns.tolist()
# Out:
# ['age',
#  'attrition',
#  'deplacements_pro',
#  'service',
#  'trajet_quotidien_en_miles',
#  'num_niveau_detude',
#  'domaine_detude',
#  'identifiant_employe',
#  'num_satisfaction_environnement',
#  'genre',
#  'num_implication',
#  'num_niveau_hierarchique',
#  'poste',
#  'num_satisfaction_travail',
#  'situation',
#  'salaire_mensuel',
#  'num_nb_entreprises',
#  'heures_sup',
#  'num_pourcentage_augmentation',
#  'num_performance',
#  'num_satisfaction_relation',
#  'num_taux_daction',
#  'tt_annee_travail',
#  'num_temps_de_formation',
#  'num_equilibre_pro_perso',
#  'annees_dans_entreprise',
#  'annees_poste_actuel',
#  'annees_depuis_promotion',
#  'num_annees_avec_manager',
#  'num_attrition',
#  'niveau_detude',
#  'satisfaction_environnement',
#  'implication',
#  'niveau_hierarchique',
#  'satisfaction_travail',
#  'performance',
#  'satisfaction_relation',
#  'taux_daction',
#  'equilibre_pro_perso',
#  'categorie_age',
#  'categorie_trajet',
#  'statut',
#  'categorie_salaire',
#  'nb_entreprises',
#  'pourcentage_augmentation',
#  'niveau_carriere',
#  'temps_de_formation',
#  'anciennete',
#  'anciennete_poste',
#  'derniere_promotion',
#  'annees_avec_manager',
#  'prenom',
#  'nom',
#  'email']

# %% [markdown]
# # Analyse des catégories le plus impactantes VS âge

# %%
colormap = ["#1d70c2", "#f87575", "#513b56"]

performance_distribution = df.groupby(["categorie_age", "performance"]).size().reset_index(name='count')

fig = px.bar(
    performance_distribution,
    x="categorie_age",
    y="count",
    color="performance",
    color_discrete_map={
        "Très élevée": colormap[0],
        "Élevée": colormap[1]
    },
    title="Niveau de performance selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de vote",
        "performance": "Niveau de performance de 1 à 4"
    },
    barmode='stack'
)
fig.update_traces(texttemplate="%{y}", textposition="inside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5b4db7f5-772c-4f45-9a1a-192501cf122b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b4db7f5-772c-4f45-9a1a-192501cf122b")) {                    Plotly.newPlot(                        "5b4db7f5-772c-4f45-9a1a-192501cf122b",                        [{"alignmentgroup":"True","hovertemplate":"Niveau de performance de 1 à 4=Très élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de vote=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Très élevée","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Très élevée","offsetgroup":"Très élevée","orientation":"v","showlegend":true,"textposition":"inside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[16,86,75,36,13],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau de performance de 1 à 4=Élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de vote=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Élevée","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Élevée","offsetgroup":"Élevée","orientation":"v","showlegend":true,"textposition":"inside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[81,468,430,209,56],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888 ...

# %% [markdown]
# Performance VS les tranches d'âge : les 25- 34 ans et 35-44 ans se sentent plus performants, ce qui est à nuancer car ils sont surreprésentés.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56"]

deplacements_pro_distribution = df.groupby(["categorie_age", "deplacements_pro"]).size().reset_index(name='count')

fig = px.bar(
    deplacements_pro_distribution,
    x="categorie_age",
    y="count",
    color="deplacements_pro",
    color_discrete_map={
        "Rare": colormap[0],
        "Fréquent": colormap[1],
        "Aucun": colormap[2]
    },
    title="Nombre de déplacements professionnels par tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de déplacement",
        "deplacements_pro": "Déplacements professionnels"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a720c80e-6fcc-4ddc-bb66-5a028868b69c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a720c80e-6fcc-4ddc-bb66-5a028868b69c")) {                    Plotly.newPlot(                        "a720c80e-6fcc-4ddc-bb66-5a028868b69c",                        [{"alignmentgroup":"True","hovertemplate":"Déplacements professionnels=Aucun\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aucun","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"Aucun","offsetgroup":"Aucun","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[12,53,56,23,6],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Déplacements professionnels=Fréquent\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fréquent","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Fréquent","offsetgroup":"Fréquent","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[15,117,96,41,8],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Déplacements professionnels=Rare\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rare","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Rare","offsetgroup":"Rare","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[70,384,353,181,55],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444 ...

# %% [markdown]
# Les déplacements professionnels VS les tranches d'âge : les déplacements restent rares.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56"]

service_distribution = df.groupby(["categorie_age", "service"]).size().reset_index(name='count')

fig = px.bar(
    service_distribution,
    x="categorie_age",
    y="count",
    color="service",
    color_discrete_map={
        "R&D": colormap[0],
        "Ventes": colormap[1],
        "RH": colormap[2]
    },
    title="Répartitions par service et par tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "service": "Service"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57df85b1-aa52-4ef7-96d3-c791b9131610" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57df85b1-aa52-4ef7-96d3-c791b9131610")) {                    Plotly.newPlot(                        "57df85b1-aa52-4ef7-96d3-c791b9131610",                        [{"alignmentgroup":"True","hovertemplate":"Service=R&D\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R&D","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"R&D","offsetgroup":"R&D","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[67,348,342,157,47],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Service=RH\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RH","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"RH","offsetgroup":"RH","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[3,22,25,9,4],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Service=Ventes\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ventes","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Ventes","offsetgroup":"Ventes","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[27,184,138,79,18],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777 ...

# %% [markdown]
# Service VS l'age : plutot egaux entre eux.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8"]

def categorize_implication(num):
    if num == 1:
        return "0-10"
    elif num == 2:
        return "10-15"
    elif num == 3:
        return "15-20"
    elif num == 4:
        return "20+"
    return None

df['niveau_implication_categorise'] = df['num_implication'].apply(categorize_implication)

niveau_detude_distribution = df.groupby(["categorie_age", "niveau_implication_categorise"]).size().reset_index(name='count')

fig = px.bar(
    niveau_detude_distribution,
    x="categorie_age",
    y="count",
    color="niveau_implication_categorise",
    color_discrete_map={
      "0-10": colormap[0],
      "10-15": colormap[1],
      "15-20": colormap[2],
      "20+": colormap[3]
    },
    title="Niveau d'implication selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "niveau_implication_categorise": "Niveau d'implication"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f5d2191-6301-4231-9581-58d8fc6955c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f5d2191-6301-4231-9581-58d8fc6955c7")) {                    Plotly.newPlot(                        "9f5d2191-6301-4231-9581-58d8fc6955c7",                        [{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=0-10\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-10","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0-10","offsetgroup":"0-10","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[3,39,26,11,4],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=10-15\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10-15","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"10-15","offsetgroup":"10-15","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[26,145,127,59,18],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=15-20\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"15-20","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"15-20","offsetgroup":"15-20","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[56,317,299,158,38],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=20+\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"20+","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"20+","offsetgroup":"20+","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[12,53,53,17,9],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444 ...

# %% [markdown]
# Niveau d'implication vs l'age : ce sont les 25-34 ans qui se sentent le moins impliqués.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8"]

niveau_detude_distribution = df.groupby(["categorie_age", "niveau_detude"]).size().reset_index(name='count')

fig = px.bar(
    niveau_detude_distribution,
    x="categorie_age",
    y="count",
    color="niveau_detude",
    color_discrete_sequence=colormap,
    title="Nombre de déplacements pro par age",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de déplacement",
        "niveau_detude": "Déplacement professionnel selon la tranche d'âge"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="aec071fc-9d92-4863-8456-4a4d629b3e22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aec071fc-9d92-4863-8456-4a4d629b3e22")) {                    Plotly.newPlot(                        "aec071fc-9d92-4863-8456-4a4d629b3e22",                        [{"alignmentgroup":"True","hovertemplate":"Déplacement professionnel selon la tranche d'âge=Bac+2\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bac+2","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Bac+2","offsetgroup":"Bac+2","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[22,97,101,52,10],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Déplacement professionnel selon la tranche d'âge=Baccalauréat\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Baccalauréat","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Baccalauréat","offsetgroup":"Baccalauréat","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[36,78,36,14,6],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Déplacement professionnel selon la tranche d'âge=Licence\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Licence","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"Licence","offsetgroup":"Licence","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[37,232,193,84,26],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Déplacement professionnel selon la tranche d'âge=Master\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Master","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"Master","offsetgroup":"Master","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[2,133,153,86,24],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Déplacement professionnel selon la tranche d'âge=Doctorat\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de déplacement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doctorat","marker":{"color":"#f0ebd8","pattern":{"shape":""}},"name":"Doctorat","offsetgroup":"Doctorat","orientation":"v","showlegend":true,"textposition":"outside","x":["25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[14,22,9,3],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d85 ...

# %% [markdown]
# Niveau d'étude VS les tranches d'age : pas vraiment parlant car sur-représentation des 25 - 34 ans et 35 - 44 ans.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8"]

niveau_detude_distribution = df.groupby(["categorie_age", "genre"]).size().reset_index(name='count')

fig = px.bar(
    niveau_detude_distribution,
    x="categorie_age",
    y="count",
    color="genre",
    color_discrete_sequence=colormap,
    title="Répartition Homme-Femme selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "genre": "Genre"
    },
    barmode='stack'
)
fig.update_traces(texttemplate="%{y}", textposition="inside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cb3380ac-c197-4a0d-ab40-aa8c3b57abdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb3380ac-c197-4a0d-ab40-aa8c3b57abdd")) {                    Plotly.newPlot(                        "cb3380ac-c197-4a0d-ab40-aa8c3b57abdd",                        [{"alignmentgroup":"True","hovertemplate":"Genre=Femme\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Femme","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Femme","offsetgroup":"Femme","orientation":"v","showlegend":true,"textposition":"inside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[37,217,196,113,25],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Genre=Homme\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Homme","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Homme","offsetgroup":"Homme","orientation":"v","showlegend":true,"textposition":"inside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[60,337,309,132,44],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d"," ...

# %% [markdown]
# Répartition Homme-Femme VS la tranche d'age : pas vraiment parlant car sur-représentation des 25 - 34 ans et 35 - 44 ans.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8"]

def categorize_implication(num):
    if num == 1:
        return "0-1"
    elif num == 2:
        return "1-2"
    elif num == 3:
        return "2-3"
    elif num == 4:
        return "3-4"
    return None

df['niveau_implication_categorise'] = df['num_implication'].apply(categorize_implication)

niveau_detude_distribution = df.groupby(["categorie_age", "niveau_implication_categorise"]).size().reset_index(name='count')

fig = px.bar(
    niveau_detude_distribution,
    x="categorie_age",
    y="count",
    color="niveau_implication_categorise",
    color_discrete_map={
      "0-1": colormap[0],
      "1-2": colormap[1],
      "2-3": colormap[2],
      "3-4": colormap[3]
    },
    title="Niveau d'implication selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "niveau_implication_categorise": "Niveau d'implication"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3c2741a8-d466-4250-8e69-0afd93ec19a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c2741a8-d466-4250-8e69-0afd93ec19a2")) {                    Plotly.newPlot(                        "3c2741a8-d466-4250-8e69-0afd93ec19a2",                        [{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=0-1\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-1","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0-1","offsetgroup":"0-1","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[3,39,26,11,4],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=1-2\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1-2","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"1-2","offsetgroup":"1-2","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[26,145,127,59,18],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=2-3\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2-3","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"2-3","offsetgroup":"2-3","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[56,317,299,158,38],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau d'implication=3-4\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3-4","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"3-4","offsetgroup":"3-4","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[12,53,53,17,9],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0. ...

# %% [markdown]
# Niveau d'implication VS Tranche d'age : 25-34 qui se sentent le moins impliqué.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136"]

def categorize_Hierarchie(num):
    if num == 1:
        return "0-1"
    elif num == 2:
        return "1-2"
    elif num == 3:
        return "2-3"
    elif num == 4:
        return "3-4"
    return None

df['niveau_hierarchique_categorise'] = df['num_niveau_hierarchique'].apply(categorize_Hierarchie)

num_hierarchique_distribution = df.groupby(["categorie_age", "niveau_hierarchique_categorise"]).size().reset_index(name='count')

fig = px.bar(
    num_hierarchique_distribution,
    x="categorie_age",
    y="count",
    color="niveau_hierarchique_categorise",
    color_discrete_map={
      "0-1": colormap[0],
      "1-2": colormap[1],
      "2-3": colormap[2],
      "3-4": colormap[3]
    },
    title="Niveau hiérarchique selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "niveau_hierarchique_categorise": "Niveau Hiérarchique"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c250dd90-a0f9-4b9a-97c6-90ae58ad75d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c250dd90-a0f9-4b9a-97c6-90ae58ad75d2")) {                    Plotly.newPlot(                        "c250dd90-a0f9-4b9a-97c6-90ae58ad75d2",                        [{"alignmentgroup":"True","hovertemplate":"Niveau Hiérarchique=0-1\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-1","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0-1","offsetgroup":"0-1","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[87,266,144,31,15],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau Hiérarchique=1-2\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1-2","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"1-2","offsetgroup":"1-2","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[10,227,213,71,13],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau Hiérarchique=2-3\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2-3","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"2-3","offsetgroup":"2-3","orientation":"v","showlegend":true,"textposition":"outside","x":["25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[56,95,55,12],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau Hiérarchique=3-4\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3-4","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"3-4","offsetgroup":"3-4","orientation":"v","showlegend":true,"textposition":"outside","x":["25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[5,29,56,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666 ...

# %% [markdown]
# Niveau Hiérarchique VS la tranche d'âge : on en apprend plus sur la composition de la masse salariale et le niveau de chaque poste.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8"]

niveau_detude_distribution = df.groupby(["poste","categorie_age",]).size().reset_index(name='count')

fig = px.bar(
    niveau_detude_distribution,
    x="poste",
    y="count",
    color="categorie_age",
    color_discrete_sequence=colormap,
    title="Répartition des postes selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "poste": "Postes"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40535ca0-f077-4812-90df-83d9b47af090" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40535ca0-f077-4812-90df-83d9b47af090")) {                    Plotly.newPlot(                        "40535ca0-f077-4812-90df-83d9b47af090",                        [{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=24 et moins\u003cbr\u003ePostes=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"24 et moins","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"24 et moins","offsetgroup":"24 et moins","orientation":"v","showlegend":true,"textposition":"outside","x":["Chercheur","Commercial","Directeur de production","Délégué médical","RH","Responsable commercial","Technicien de laboratoire"],"xaxis":"x","y":[30,23,4,1,3,4,32],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=25 - 34\u003cbr\u003ePostes=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"25 - 34","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"25 - 34","offsetgroup":"25 - 34","orientation":"v","showlegend":true,"textposition":"outside","x":["Chercheur","Commercial","Directeur R&D","Directeur de production","Délégué médical","Manager","RH","Responsable commercial","Technicien de laboratoire"],"xaxis":"x","y":[144,38,13,44,35,7,22,144,107],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=35 - 44\u003cbr\u003ePostes=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"35 - 44","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"35 - 44","offsetgroup":"35 - 44","orientation":"v","showlegend":true,"textposition":"outside","x":["Chercheur","Commercial","Directeur R&D","Directeur de production","Délégué médical","Manager","RH","Responsable commercial","Technicien de laboratoire"],"xaxis":"x","y":[85,14,27,61,60,31,21,115,91],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=45 - 54\u003cbr\u003ePostes=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"45 - 54","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"45 - 54","offsetgroup":"45 - 54","orientation":"v","showlegend":true,"textposition":"outside","x":["Chercheur","Commercial","Directeur R&D","Directeur de production","Délégué médical","Manager","RH","Responsable commercial","Technicien de laboratoire"],"xaxis":"x","y":[22,8,34,30,24,47,5,51,24],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=55 et plus\u003cbr\u003ePostes=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"55 et plus","marker":{"color":"#f0ebd8","pattern":{"shape":""}},"name":"55 et plus","offsetgroup":"55 et plus","orientation":"v","showlegend":true,"textposition":"outside","x":["Chercheur","Directeur R&D","Directeur de production","Délégué médical","Manager","RH","Responsable commercial","Technicien de laboratoire"],"xaxis":"x","y":[11,6,6,11,17,1,12,5],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorba ...

# %% [markdown]
# Poste VS la tranche d'âge : Sur représentations des Chercheurs, Responsables commerciaux et Technicien de laboratoire.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136"]

def categorize_satisfaction(num):
    if num == 1:
        return "0-1"
    elif num == 2:
        return "1-2"
    elif num == 3:
        return "2-3"
    elif num == 4:
        return "3-4"
    return None

df['niveau_satisfaction_categorise'] = df['num_satisfaction_travail'].apply(categorize_satisfaction)

num_hierarchique_distribution = df.groupby(["categorie_age", "niveau_satisfaction_categorise"]).size().reset_index(name='count')

fig = px.bar(
    num_hierarchique_distribution,
    x="categorie_age",
    y="count",
    color="niveau_satisfaction_categorise",
    color_discrete_map={
      "0-1": colormap[0],
      "1-2": colormap[1],
      "2-3": colormap[2],
      "3-4": colormap[3]
    },
    title="Niveau de satisfaction selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "niveau_satisfaction_categorise": "Niveau de satisfaction de 1-4"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="befc3dac-6141-465d-a8a8-a65f033c5804" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("befc3dac-6141-465d-a8a8-a65f033c5804")) {                    Plotly.newPlot(                        "befc3dac-6141-465d-a8a8-a65f033c5804",                        [{"alignmentgroup":"True","hovertemplate":"Niveau de satisfaction de 1-4=0-1\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-1","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0-1","offsetgroup":"0-1","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[17,113,97,46,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau de satisfaction de 1-4=1-2\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1-2","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"1-2","offsetgroup":"1-2","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[19,102,95,50,14],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau de satisfaction de 1-4=2-3\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2-3","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"2-3","offsetgroup":"2-3","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[33,159,153,81,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Niveau de satisfaction de 1-4=3-4\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3-4","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"3-4","offsetgroup":"3-4","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[28,180,160,68,23],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c1 ...

# %% [markdown]
# Niveau de satisfaction vs la tranche d'âge : les 25 - 34 ans et 35 - 44 ans ont un indice de satisfaction à 1 relativement élevé.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136"]

sat_relation_distribution = df.groupby(["categorie_age","satisfaction_relation"]).size().reset_index(name='count')

fig = px.bar(
    sat_relation_distribution,
    x="categorie_age",
    y="count",
    color="satisfaction_relation",
    color_discrete_map={
       "Faible" : colormap[0],
       "Moyenne": colormap[1],
       "Élevée": colormap[2],
       "Très élevée": colormap[3]
    },
    title="Indice relationnel selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "satisfaction_relation": "Indice relationnel"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c960a8d2-e7c8-4bb5-bae5-4f71b1b6ddb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c960a8d2-e7c8-4bb5-bae5-4f71b1b6ddb3")) {                    Plotly.newPlot(                        "c960a8d2-e7c8-4bb5-bae5-4f71b1b6ddb3",                        [{"alignmentgroup":"True","hovertemplate":"Indice relationnel=Faible\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faible","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Faible","offsetgroup":"Faible","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[22,104,98,41,11],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice relationnel=Moyenne\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moyenne","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Moyenne","offsetgroup":"Moyenne","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[17,113,113,50,10],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice relationnel=Très élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Très élevée","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"Très élevée","offsetgroup":"Très élevée","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[28,156,146,70,32],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice relationnel=Élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Élevée","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"Élevée","offsetgroup":"Élevée","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[30,181,148,84,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a ...

# %% [markdown]
# Niveau de satifaction interprofessionnel VS les tranches d'âge : les 25 - 34 ans et 35 - 44 ans ont un indice de interprofessionnel à 1 relativement élevé.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136"]

sat_environnement_distribution = df.groupby(["categorie_age","satisfaction_environnement"]).size().reset_index(name='count')

fig = px.bar(
   sat_environnement_distribution,
    x="categorie_age",
    y="count",
    color="satisfaction_environnement",
    color_discrete_map={
       "Faible" : colormap[0],
       "Moyenne": colormap[1],
       "Élevée": colormap[2],
       "Très élevée": colormap[3]
    },
    title="Indice de satifaction sur l'environnement professionnel selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "satisfaction_environnement": "Indice satifaction environnement"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7af304d0-8e12-4e32-b45a-8b241b52c75c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7af304d0-8e12-4e32-b45a-8b241b52c75c")) {                    Plotly.newPlot(                        "7af304d0-8e12-4e32-b45a-8b241b52c75c",                        [{"alignmentgroup":"True","hovertemplate":"Indice satifaction environnement=Faible\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faible","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Faible","offsetgroup":"Faible","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[20,105,93,52,14],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice satifaction environnement=Moyenne\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moyenne","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Moyenne","offsetgroup":"Moyenne","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[19,109,110,39,10],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice satifaction environnement=Très élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Très élevée","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"Très élevée","offsetgroup":"Très élevée","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[32,165,145,81,23],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice satifaction environnement=Élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Élevée","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"Élevée","offsetgroup":"Élevée","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[26,175,157,73,22],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0 ...

# %% [markdown]
# Indice de satifaction environnement VS les tranches d'âge : les 25 - 34 ans et 35 - 44 ans ont un indice de interprofessionnel à 1 relativement élevé.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136"]

sat_travail_distribution = df.groupby(["categorie_age","satisfaction_travail"]).size().reset_index(name='count')

fig = px.bar(
   sat_travail_distribution,
    x="categorie_age",
    y="count",
    color="satisfaction_travail",
    color_discrete_map={
       "Faible" : colormap[0],
       "Moyenne": colormap[1],
       "Élevée": colormap[2],
       "Très élevée": colormap[3]
    },
    title="Indice de satifaction sur la mission selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "satisfaction_travail": "Indice satifaction de la mission"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c2418c9c-51b6-4546-9f2c-429ca3028e9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2418c9c-51b6-4546-9f2c-429ca3028e9b")) {                    Plotly.newPlot(                        "c2418c9c-51b6-4546-9f2c-429ca3028e9b",                        [{"alignmentgroup":"True","hovertemplate":"Indice satifaction de la mission=Faible\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faible","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Faible","offsetgroup":"Faible","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[17,113,97,46,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice satifaction de la mission=Moyenne\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Moyenne","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Moyenne","offsetgroup":"Moyenne","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[19,102,95,50,14],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice satifaction de la mission=Très élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Très élevée","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"Très élevée","offsetgroup":"Très élevée","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[28,180,160,68,23],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Indice satifaction de la mission=Élevée\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Élevée","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"Élevée","offsetgroup":"Élevée","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[33,159,153,81,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0. ...

# %% [markdown]
# Indice de satifaction travail VS les tranches d'âge : les 25 - 34 ans et 35 - 44 ans ont un Indice satifaction de la mission faible relativement élevé.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8"]

niveau_detude_distribution = df.groupby(["situation","categorie_age",]).size().reset_index(name='count')

fig = px.bar(
    niveau_detude_distribution,
    x="categorie_age",
    y="count",
    color="situation",
    color_discrete_map={
       "Célibataire" : colormap[0],
       "Marié(e)": colormap[1],
       "Divorcé(e)": colormap[2]
    },
    title="Situation selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "poste": "Poste"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="640329a6-9986-442c-abe1-d7bbeeb7f07e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("640329a6-9986-442c-abe1-d7bbeeb7f07e")) {                    Plotly.newPlot(                        "640329a6-9986-442c-abe1-d7bbeeb7f07e",                        [{"alignmentgroup":"True","hovertemplate":"situation=Célibataire\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Célibataire","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Célibataire","offsetgroup":"Célibataire","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[56,184,147,64,19],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"situation=Divorcé(e)\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Divorcé(e)","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"Divorcé(e)","offsetgroup":"Divorcé(e)","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[11,127,119,54,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"situation=Marié(e)\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Marié(e)","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Marié(e)","offsetgroup":"Marié(e)","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[30,243,239,127,34],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444444 ...

# %% [markdown]
# Situation Vs la tranche d'age : une majorité de l'effectifs est célibataire ou marié.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8", "#3D315B", "#BADEFC", "#C49BBB", "#FFC6D9"]

salary_age_distribution = df.groupby(["categorie_salaire", "categorie_age"]).size().reset_index(name='count')

fig = px.bar(
    salary_age_distribution,
    x="categorie_salaire",
    y="count",
    color="categorie_age",
    color_discrete_map={
      "24 et moins": colormap[0],
      "25 - 34": colormap[1],
      "35 - 44": colormap[2],
      "45 - 54": colormap[3],
      "55 et plus": colormap[4]
    },
    title="Niveau de salaire mensuel selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "categorie_salaire": "Niveau de salaire mensuel"
    },
    barmode='stack'
)
fig.update_traces(texttemplate="%{y}", textposition="inside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c1e0c31-8a8a-49b7-9772-09b267bac1dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c1e0c31-8a8a-49b7-9772-09b267bac1dd")) {                    Plotly.newPlot(                        "5c1e0c31-8a8a-49b7-9772-09b267bac1dd",                        [{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=24 et moins\u003cbr\u003eNiveau de salaire mensuel=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"24 et moins","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"24 et moins","offsetgroup":"24 et moins","orientation":"v","showlegend":true,"textposition":"inside","x":["0 - 2696","2697 - 4229","4230 - 5743"],"xaxis":"x","y":[55,35,7],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=25 - 34\u003cbr\u003eNiveau de salaire mensuel=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"25 - 34","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"25 - 34","offsetgroup":"25 - 34","orientation":"v","showlegend":true,"textposition":"inside","x":["0 - 2696","2697 - 4229","4230 - 5743","5744 - 9860","9861 +"],"xaxis":"x","y":[136,144,121,121,32],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=35 - 44\u003cbr\u003eNiveau de salaire mensuel=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"35 - 44","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"35 - 44","offsetgroup":"35 - 44","orientation":"v","showlegend":true,"textposition":"inside","x":["0 - 2696","2697 - 4229","4230 - 5743","5744 - 9860","9861 +"],"xaxis":"x","y":[76,88,113,125,103],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=45 - 54\u003cbr\u003eNiveau de salaire mensuel=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"45 - 54","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"45 - 54","offsetgroup":"45 - 54","orientation":"v","showlegend":true,"textposition":"inside","x":["0 - 2696","2697 - 4229","4230 - 5743","5744 - 9860","9861 +"],"xaxis":"x","y":[18,22,42,42,121],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=55 et plus\u003cbr\u003eNiveau de salaire mensuel=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"55 et plus","marker":{"color":"#f0ebd8","pattern":{"shape":""}},"name":"55 et plus","offsetgroup":"55 et plus","orientation":"v","showlegend":true,"textposition":"inside","x":["0 - 2696","2697 - 4229","4230 - 5743","5744 - 9860","9861 +"],"xaxis":"x","y":[10,4,11,6,38],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1. ...

# %% [markdown]
# Salaire mensuel VS les tranches d'âge

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8", "#3D315B", "#BADEFC", "#C49BBB", "#FFC6D9"]


salary_age_distribution = df.groupby(["categorie_age", "heures_sup"]).size().reset_index(name='count')

fig = px.bar(
    salary_age_distribution,
    x="categorie_age",
    y="count",
    color="heures_sup",
    color_discrete_map={
      "Non": colormap[0],
      "Oui": colormap[1]
    },
    title="Répartition des heures supplémentaires selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "heures_sup": "Heures supplémentaires"
    },
    barmode='stack'
)
fig.update_traces(texttemplate="%{y}", textposition="inside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="be183513-b7bc-46b6-9d25-a1bc8bd8b609" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be183513-b7bc-46b6-9d25-a1bc8bd8b609")) {                    Plotly.newPlot(                        "be183513-b7bc-46b6-9d25-a1bc8bd8b609",                        [{"alignmentgroup":"True","hovertemplate":"Heures supplémentaires=Non\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"Non","offsetgroup":"Non","orientation":"v","showlegend":true,"textposition":"inside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[66,413,354,179,42],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Heures supplémentaires=Oui\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oui","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"Oui","offsetgroup":"Oui","orientation":"v","showlegend":true,"textposition":"inside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[31,141,151,66,27],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{ ...

# %% [markdown]
# Heures supplémentaires par tranche d'âge : la proportion reste identique en fonction des tranches d'âge.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8", "#3D315B", "#BADEFC", "#C49BBB", "#FFC6D9"]

def categorize_augmentation(num):
    if 0 <= num <= 13:
        return "0-13"
    elif 14 <= num <= 18:
        return "14-18"
    elif 19 <= num <= 22:
        return "19-22"
    elif num > 22:
        return "22+"
    return None

df['num_pourcentage_augmentation_cat'] = df['num_pourcentage_augmentation'].apply(categorize_augmentation)

augmentation_distribution = df.groupby(["categorie_age", "num_pourcentage_augmentation_cat"]).size().reset_index(name='count')

fig = px.bar(
    augmentation_distribution,
    x="categorie_age",
    y="count",
    color="num_pourcentage_augmentation_cat",
    color_discrete_map={
      "0-13": colormap[0],
      "14-18": colormap[1],
      "19-22": colormap[2],
      "22+": colormap[3]
    },
    title="Pourcentage d'augmentation selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "num_pourcentage_augmentation_cat": "Pourcentage d'augmentation" # Corrected label key
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7f2c5bf4-e187-4493-8d48-bc1028d30426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f2c5bf4-e187-4493-8d48-bc1028d30426")) {                    Plotly.newPlot(                        "7f2c5bf4-e187-4493-8d48-bc1028d30426",                        [{"alignmentgroup":"True","hovertemplate":"Pourcentage d'augmentation=0-13\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-13","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0-13","offsetgroup":"0-13","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[40,246,209,96,26],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Pourcentage d'augmentation=14-18\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"14-18","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"14-18","offsetgroup":"14-18","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[35,191,199,99,27],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Pourcentage d'augmentation=19-22\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"19-22","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"19-22","offsetgroup":"19-22","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[17,91,77,37,13],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Pourcentage d'augmentation=22+\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"22+","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"22+","offsetgroup":"22+","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[5,26,20,13,3],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...

# %% [markdown]
# Pourcentage d'augmentation vs l'âge : sur représentation donc pas d'informations qui sautent aux yeux.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8", "#3D315B", "#BADEFC", "#C49BBB", "#FFC6D9"]


colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136"]

def categorie_action(num):
    if num == 1:
        return "0-1"
    elif num == 2:
        return "1-2"
    elif num == 3:
        return "2-3"
    elif num == 4:
        return "3-4"
    return None

df['action_cat'] = df['num_taux_daction'].apply(categorie_action)

action_distribution = df.groupby(["categorie_age", "action_cat"]).size().reset_index(name='count')

fig = px.bar(
    action_distribution,
    x="categorie_age",
    y="count",
    color="action_cat",
    color_discrete_map={
      "0-1": colormap[0],
      "1-2": colormap[1],
      "2-3": colormap[2],
      "3-4": colormap[3]
    },
    title="Taux d'action selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "action_cat": "Taux d'action de 1-3"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="72f5a260-1753-4a1a-a7f2-25af8a3af799" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72f5a260-1753-4a1a-a7f2-25af8a3af799")) {                    Plotly.newPlot(                        "72f5a260-1753-4a1a-a7f2-25af8a3af799",                        [{"alignmentgroup":"True","hovertemplate":"Taux d'action de 1-3=0-1\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-1","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0-1","offsetgroup":"0-1","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[25,204,225,108,34],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Taux d'action de 1-3=1-2\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1-2","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"1-2","offsetgroup":"1-2","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[9,63,55,28,3],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Taux d'action de 1-3=2-3\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2-3","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"2-3","offsetgroup":"2-3","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[3,39,26,12,5],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %% [markdown]
# Taux d'action VS l'âge

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#6a0136", "#f0ebd8", "#3D315B", "#BADEFC", "#C49BBB", "#FFC6D9"]

anciennete_distribution = df.groupby(["categorie_age","anciennete"]).size().reset_index(name='count')

fig = px.bar(
    anciennete_distribution,
    x="categorie_age",
    y="count",
    color="anciennete",
    color_discrete_map={
      "0 - 02": colormap[0],
      "03 - 05": colormap[1],
      "06 - 10": colormap[2],
      "10 - 20": colormap[3],
      "21+": colormap[4]
    },
    title="répartition de l'ancienneté de l'effectif selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "anciennete": "Ancienneté des collaborateurs"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="42535f76-9d23-4068-9366-435f23b6bc93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42535f76-9d23-4068-9366-435f23b6bc93")) {                    Plotly.newPlot(                        "42535f76-9d23-4068-9366-435f23b6bc93",                        [{"alignmentgroup":"True","hovertemplate":"Ancienneté des collaborateurs=0 - 02\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0 - 02","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0 - 02","offsetgroup":"0 - 02","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[65,115,106,40,16],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Ancienneté des collaborateurs=03 - 05\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"03 - 05","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"03 - 05","offsetgroup":"03 - 05","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[28,187,134,67,18],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Ancienneté des collaborateurs=06 - 10\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"06 - 10","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"06 - 10","offsetgroup":"06 - 10","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[4,202,147,77,18],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Ancienneté des collaborateurs=10 - 20\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10 - 20","marker":{"color":"#6a0136","pattern":{"shape":""}},"name":"10 - 20","offsetgroup":"10 - 20","orientation":"v","showlegend":true,"textposition":"outside","x":["25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[50,91,31,8],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"Ancienneté des collaborateurs=21 +\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"21 +","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"21 +","offsetgroup":"21 +","orientation":"v","showlegend":true,"textposition":"outside","x":["35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[27,30,9],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlin ...

# %% [markdown]
# Ancienneté par tranche d'âge : on remarque une belle proportion des 35 - 44 ans qui on fait toute leur carrière chez IBM.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#f0ebd8", "#3D315B", "#BADEFC", "#C49BBB", "#FFC6D9"]

promotion_distribution = df.groupby(["categorie_age","derniere_promotion"]).size().reset_index(name='count')

fig = px.bar(
   promotion_distribution,
    x="categorie_age",
    y="count",
    color="derniere_promotion",
    color_discrete_map={
      "0 - 02": colormap[0],
      "03 - 05": colormap[1],
      "06 - 10": colormap[2],
      "10+": colormap[3]
    },
    title="répartition de l'ancienneté de l'effectif selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "anciennete": "Ancienneté des collaborateurs"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0c12af1a-ac0c-4560-a53e-369440df63fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c12af1a-ac0c-4560-a53e-369440df63fd")) {                    Plotly.newPlot(                        "0c12af1a-ac0c-4560-a53e-369440df63fd",                        [{"alignmentgroup":"True","hovertemplate":"derniere_promotion=0 - 02\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0 - 02","marker":{"color":"#1d70c2","pattern":{"shape":""}},"name":"0 - 02","offsetgroup":"0 - 02","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[95,439,355,162,46],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"derniere_promotion=03 - 05\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"03 - 05","marker":{"color":"#f87575","pattern":{"shape":""}},"name":"03 - 05","offsetgroup":"03 - 05","orientation":"v","showlegend":true,"textposition":"outside","x":["24 et moins","25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[2,54,60,35,7],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"derniere_promotion=06 - 10\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"06 - 10","marker":{"color":"#513b56","pattern":{"shape":""}},"name":"06 - 10","offsetgroup":"06 - 10","orientation":"v","showlegend":true,"textposition":"outside","x":["25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[60,54,26,9],"yaxis":"y","type":"bar","texttemplate":"%{y}"},{"alignmentgroup":"True","hovertemplate":"derniere_promotion=10 +\u003cbr\u003eTranche d'âge=%{x}\u003cbr\u003eNombre de personne=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10 +","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"10 +","offsetgroup":"10 +","orientation":"v","showlegend":true,"textposition":"outside","x":["25 - 34","35 - 44","45 - 54","55 et plus"],"xaxis":"x","y":[1,36,22,7],"yaxis":"y","type":"bar","texttemplate":"%{y}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[ ...

# %% [markdown]
# Ancienneté VS Age : comme vu sur unilatérale, l'effectif total passe rarement plus de 2 ans sans promotion.

# %%
colormap = ["#1d70c2", "#f87575", "#513b56", "#f0ebd8", "#3D315B", "#BADEFC", "#C49BBB", "#FFC6D9"]

promotion_distribution = df.groupby(["categorie_age","derniere_promotion"]).size().reset_index(name='count')

fig = px.bar(
   promotion_distribution,
    x="categorie_age",
    y="count",
    color="derniere_promotion",
    color_discrete_map={
      "0 - 02": colormap[0],
      "03 - 05": colormap[1],
      "06 - 10": colormap[2],
      "10+": colormap[3]
    },
    title="répartition de l'ancienneté de l'effectif selon la tranche d'âge",
    labels={
        "categorie_age": "Tranche d'âge",
        "count": "Nombre de personne",
        "anciennete": "Ancienneté des collaborateurs"
    },
    barmode='group'
)
fig.update_traces(texttemplate="%{y}", textposition="outside")
fig.show()
